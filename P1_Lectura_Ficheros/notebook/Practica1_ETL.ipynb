# %% [markdown]
# 27/11/2020

# %% [markdown]
# Isabel Afán de Ribera

# %% [markdown]
# ## Práctica 1: Generación de ficheros de metadatos y lectura de formatos en Python

# %% [markdown]
# Esta tarea consiste en, buscar información sobre los formatos json y yaml, e implementar sendas funciones ya sea en R o en python (como en este caso), para poder leer este tipo de ficheros. ¿Se pueden leer con spark? ¿Qué tipo de bases de datos No SQL usa estructuras de datos similares?

# %% [markdown]
# ### Sobre ambos formatos

# %% [markdown]
# Tanto JSON como YAML son lenguajes de serialización de datos siendo este el proceso de convertir objetos de datos presentes en estructuras de datos complejas en un flujo de bytes para fines de almacenamiento, transferencia y distribución en dispositivos físicos. Por tanto, ambos son una forma de almacenar objetos y estructuras de datos en archivos.

# %% [markdown]
# ### Formato JSON

# %% [markdown]
# JavaScript Object Notation (JSON) es un formato basado en texto estándar para representar datos estructurados en la sintaxis de objetos de JavaScript. Aunque puede ser utilizado independientemente de JavaScript, y muchos entornos de programación poseen la capacidad de leer (convertir; parsear) y generar JSON.

# %% [markdown]
# JSON tiene un formato estándar para el almacenamiento de datos. Almacena datos en pares clave / valor. Los registros están separados por comas y tanto los nombres de los campos como las cadenas están entre comillas dobles.

# %% [markdown]
# Algunos de los tipos de datos válidos utilizados en JSON son:

# %% [markdown]
# * Números
# * Strings
# * Objetos
# * Arrays

# %%
# base de datos obtenida de datos abiertos de la Comunidad de Madrid relativa a información epidemiológica Covid-19 de Madrid
import json
dataset = open("covid19_tia_muni_y_distritos_s.json", encoding="utf8")
data = json.load(dataset)
data
# Out:
# {'data': [{'municipio_distrito': 'Madrid-Retiro',
#    'codigo_geometria': '079603',
#    'tasa_incidencia_acumulada_ultimos_14dias': 264.002614883043,
#    'tasa_incidencia_acumulada_total': 4700.92275199678,
#    'casos_confirmados_totales': 5609,
#    'casos_confirmados_ultimos_14dias': 315,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Salamanca',
#    'codigo_geometria': '079604',
#    'tasa_incidencia_acumulada_ultimos_14dias': 331.955319498439,
#    'tasa_incidencia_acumulada_total': 4740.45885122926,
#    'casos_confirmados_totales': 6926,
#    'casos_confirmados_ultimos_14dias': 485,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Centro',
#    'codigo_geometria': '079601',
#    'tasa_incidencia_acumulada_ultimos_14dias': 289.956098718557,
#    'tasa_incidencia_acumulada_total': 5056.06312292359,
#    'casos_confirmados_totales': 6818,
#    'casos_confirmados_ultimos_14dias': 391,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Arganzuela',
#    'codigo_geometria': '079602',
#    'tasa_incidencia_acumulada_ultimos_14dias': 230.164561159405,
#    'tasa_incidencia_acumulada_total': 4784.04192375961,
#    'casos_confirmados_totales': 7358,
#    'casos_confirmados_ultimos_14dias': 354,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Chamartín',
#    'codigo_geometria': '079605',
#    'tasa_incidencia_acumulada_ultimos_14dias': 269.456766930181,
#    'tasa_incidencia_acumulada_total': 4505.34456869776,
#    'casos_confirmados_totales': 6571,
#    'casos_confirmados_ultimos_14dias': 393,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Tetuán',
#    'codigo_geometria': '079606',
#    'tasa_incidencia_acumulada_ultimos_14dias': 249.33079361865,
#    'tasa_incidencia_acumulada_total': 5263.15789473684,
#    'casos_confirmados_totales': 8317,
#    'casos_confirmados_ultimos_14dias': 394,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Chamberí',
#    'codigo_geometria': '079607',
#    'tasa_incidencia_acumulada_ultimos_14dias': 317.838411812396,
#    'tasa_incidencia_acumulada_total': 4811.34173727749,
#    'casos_confirmados_totales': 6706,
#    'casos_confirmados_ultimos_14dias': 443,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Fuencarral-El Pardo',
#    'codigo_geometria': '079608',
#    'tasa_incidencia_acumulada_ultimos_14dias': 256.974290372816,
#    'tasa_incidencia_acumulada_total': 4293.34103171925,
#    'casos_confirmados_totales': 10559,
#    'casos_confirmados_ultimos_14dias': 632,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Moncloa-Aravaca',
#    'codigo_geometria': '079609',
#    'tasa_incidencia_acumulada_ultimos_14dias': 298.110015994105,
#    'tasa_incidencia_acumulada_total': 4932.21346686876,
#    'casos_confirmados_totales': 5890,
#    'casos_confirmados_ultimos_14dias': 356,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Latina',
#    'codigo_geometria': '079610',
#    'tasa_incidencia_acumulada_ultimos_14dias': 238.856845410506,
#    'tasa_incidencia_acumulada_total': 5396.31765861522,
#    'casos_confirmados_totales': 12855,
#    'casos_confirmados_ultimos_14dias': 569,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Carabanchel',
#    'codigo_geometria': '079611',
#    'tasa_incidencia_acumulada_ultimos_14dias': 279.732436714487,
#    'tasa_incidencia_acumulada_total': 6332.30475031509,
#    'casos_confirmados_totales': 16027,
#    'casos_confirmados_ultimos_14dias': 708,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Usera',
#    'codigo_geometria': '079612',
#    'tasa_incidencia_acumulada_ultimos_14dias': 203.948733728827,
#    'tasa_incidencia_acumulada_total': 6819.75941205516,
#    'casos_confirmados_totales': 9530,
#    'casos_confirmados_ultimos_14dias': 285,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Puente de Vallecas',
#    'codigo_geometria': '079613',
#    'tasa_incidencia_acumulada_ultimos_14dias': 327.859080206253,
#    'tasa_incidencia_acumulada_total': 8052.55964267618,
#    'casos_confirmados_totales': 18912,
#    'casos_confirmados_ultimos_14dias': 770,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-San Blas - Canillejas',
#    'codigo_geometria': '079620',
#    'tasa_incidencia_acumulada_ultimos_14dias': 269.378153811132,
#    'tasa_incidencia_acumulada_total': 4948.08463279837,
#    'casos_confirmados_totales': 7825,
#    'casos_confirmados_ultimos_14dias': 426,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Barajas',
#    'codigo_geometria': '079621',
#    'tasa_incidencia_acumulada_ultimos_14dias': 230.871386249872,
#    'tasa_incidencia_acumulada_total': 4061.70191030749,
#    'casos_confirmados_totales': 1988,
#    'casos_confirmados_ultimos_14dias': 113,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Moratalaz',
#    'codigo_geometria': '079614',
#    'tasa_incidencia_acumulada_ultimos_14dias': 322.512424658983,
#    'tasa_incidencia_acumulada_total': 5590.56783335096,
#    'casos_confirmados_totales': 5287,
#    'casos_confirmados_ultimos_14dias': 305,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Ciudad Lineal',
#    'codigo_geometria': '079615',
#    'tasa_incidencia_acumulada_ultimos_14dias': 316.250855356846,
#    'tasa_incidencia_acumulada_total': 5469.19790645633,
#    'casos_confirmados_totales': 11829,
#    'casos_confirmados_ultimos_14dias': 684,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Hortaleza',
#    'codigo_geometria': '079616',
#    'tasa_incidencia_acumulada_ultimos_14dias': 306.07852827241,
#    'tasa_incidencia_acumulada_total': 4163.4119253721,
#    'casos_confirmados_totales': 7835,
#    'casos_confirmados_ultimos_14dias': 576,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Villaverde',
#    'codigo_geometria': '079617',
#    'tasa_incidencia_acumulada_ultimos_14dias': 260.497092906154,
#    'tasa_incidencia_acumulada_total': 6674.23092933009,
#    'casos_confirmados_totales': 9941,
#    'casos_confirmados_ultimos_14dias': 388,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Villa de Vallecas',
#    'codigo_geometria': '079618',
#    'tasa_incidencia_acumulada_ultimos_14dias': 251.891451094097,
#    'tasa_incidencia_acumulada_total': 5544.33017713949,
#    'casos_confirmados_totales': 6119,
#    'casos_confirmados_ultimos_14dias': 278,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madrid-Vicálvaro',
#    'codigo_geometria': '079619',
#    'tasa_incidencia_acumulada_ultimos_14dias': 344.009654464496,
#    'tasa_incidencia_acumulada_total': 5323.82682997878,
#    'casos_confirmados_totales': 3838,
#    'casos_confirmados_ultimos_14dias': 248,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Pozuelo de Alarcón',
#    'codigo_geometria': '1150',
#    'tasa_incidencia_acumulada_ultimos_14dias': 273.078614241744,
#    'tasa_incidencia_acumulada_total': 4113.53590520932,
#    'casos_confirmados_totales': 3555,
#    'casos_confirmados_ultimos_14dias': 236,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Alcorcón',
#    'codigo_geometria': '0072',
#    'tasa_incidencia_acumulada_ultimos_14dias': 233.99838136458,
#    'tasa_incidencia_acumulada_total': 4508.13422944744,
#    'casos_confirmados_totales': 7687,
#    'casos_confirmados_ultimos_14dias': 399,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Navalcarnero',
#    'codigo_geometria': '0967',
#    'tasa_incidencia_acumulada_ultimos_14dias': 337.907024370264,
#    'tasa_incidencia_acumulada_total': 3351.76462557171,
#    'casos_confirmados_totales': 982,
#    'casos_confirmados_ultimos_14dias': 99,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'San Agustín del Guadalix',
#    'codigo_geometria': '1296',
#    'tasa_incidencia_acumulada_ultimos_14dias': 343.822408251738,
#    'tasa_incidencia_acumulada_total': 4686.44891247477,
#    'casos_confirmados_totales': 627,
#    'casos_confirmados_ultimos_14dias': 46,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Las Rozas de Madrid',
#    'codigo_geometria': '1277',
#    'tasa_incidencia_acumulada_ultimos_14dias': 295.363934289352,
#    'tasa_incidencia_acumulada_total': 3579.8526311395,
#    'casos_confirmados_totales': 3430,
#    'casos_confirmados_ultimos_14dias': 283,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Moraleja de Enmedio',
#    'codigo_geometria': '0894',
#    'tasa_incidencia_acumulada_ultimos_14dias': 214.17445482866,
#    'tasa_incidencia_acumulada_total': 5704.82866043614,
#    'casos_confirmados_totales': 293,
#    'casos_confirmados_ultimos_14dias': 11,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdaracete',
#    'codigo_geometria': '1551',
#    'tasa_incidencia_acumulada_ultimos_14dias': 328.407224958949,
#    'tasa_incidencia_acumulada_total': 7553.36617405583,
#    'casos_confirmados_totales': 46,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Pozuelo del Rey',
#    'codigo_geometria': '1163',
#    'tasa_incidencia_acumulada_ultimos_14dias': 87.1839581517001,
#    'tasa_incidencia_acumulada_total': 1918.0470793374,
#    'casos_confirmados_totales': 22,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Puebla de la Sierra',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 0.0,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Perales de Tajuña',
#    'codigo_geometria': '1104',
#    'tasa_incidencia_acumulada_ultimos_14dias': 511.073253833049,
#    'tasa_incidencia_acumulada_total': 5247.01873935264,
#    'casos_confirmados_totales': 154,
#    'casos_confirmados_ultimos_14dias': 15,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdemorillo',
#    'codigo_geometria': '1603',
#    'tasa_incidencia_acumulada_ultimos_14dias': 231.666400383448,
#    'tasa_incidencia_acumulada_total': 3147.46764658891,
#    'casos_confirmados_totales': 394,
#    'casos_confirmados_ultimos_14dias': 29,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Navalafuente',
#    'codigo_geometria': '0941',
#    'tasa_incidencia_acumulada_ultimos_14dias': 276.052449965493,
#    'tasa_incidencia_acumulada_total': 3588.68184955141,
#    'casos_confirmados_totales': 52,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Velilla de San Antonio',
#    'codigo_geometria': '1678',
#    'tasa_incidencia_acumulada_ultimos_14dias': 245.1781627983,
#    'tasa_incidencia_acumulada_total': 4094.47531873161,
#    'casos_confirmados_totales': 501,
#    'casos_confirmados_ultimos_14dias': 30,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Villanueva de la Cañada',
#    'codigo_geometria': '1760',
#    'tasa_incidencia_acumulada_ultimos_14dias': 424.341338307298,
#    'tasa_incidencia_acumulada_total': 3604.56982979716,
#    'casos_confirmados_totales': 773,
#    'casos_confirmados_ultimos_14dias': 91,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Villanueva del Pardillo',
#    'codigo_geometria': '1776',
#    'tasa_incidencia_acumulada_ultimos_14dias': 267.753201396973,
#    'tasa_incidencia_acumulada_total': 3364.37718277066,
#    'casos_confirmados_totales': 578,
#    'casos_confirmados_ultimos_14dias': 46,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Nuevo Baztán',
#    'codigo_geometria': '1006',
#    'tasa_incidencia_acumulada_ultimos_14dias': 143.4034416826,
#    'tasa_incidencia_acumulada_total': 3664.75462077757,
#    'casos_confirmados_totales': 230,
#    'casos_confirmados_ultimos_14dias': 9,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Villamantilla',
#    'codigo_geometria': '1757',
#    'tasa_incidencia_acumulada_ultimos_14dias': 971.547536433033,
#    'tasa_incidencia_acumulada_total': 3539.20888272033,
#    'casos_confirmados_totales': 51,
#    'casos_confirmados_ultimos_14dias': 14,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Villamanta',
#    'codigo_geometria': '1744',
#    'tasa_incidencia_acumulada_ultimos_14dias': 117.416829745597,
#    'tasa_incidencia_acumulada_total': 3600.78277886497,
#    'casos_confirmados_totales': 92,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Cabanillas de la Sierra',
#    'codigo_geometria': '0297',
#    'tasa_incidencia_acumulada_ultimos_14dias': 264.550264550265,
#    'tasa_incidencia_acumulada_total': 5952.38095238095,
#    'casos_confirmados_totales': 45,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Cenicientos',
#    'codigo_geometria': '0376',
#    'tasa_incidencia_acumulada_ultimos_14dias': 98.3767830791933,
#    'tasa_incidencia_acumulada_total': 4672.89719626168,
#    'casos_confirmados_totales': 95,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Puentes Viejas',
#    'codigo_geometria': '9020',
#    'tasa_incidencia_acumulada_ultimos_14dias': 441.826215022091,
#    'tasa_incidencia_acumulada_total': 2798.23269513991,
#    'casos_confirmados_totales': 19,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Aranjuez',
#    'codigo_geometria': '0133',
#    'tasa_incidencia_acumulada_ultimos_14dias': 286.879057828778,
#    'tasa_incidencia_acumulada_total': 4412.23346251279,
#    'casos_confirmados_totales': 2630,
#    'casos_confirmados_ultimos_14dias': 171,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Cercedilla',
#    'codigo_geometria': '0382',
#    'tasa_incidencia_acumulada_ultimos_14dias': 213.492741246798,
#    'tasa_incidencia_acumulada_total': 4938.79874750925,
#    'casos_confirmados_totales': 347,
#    'casos_confirmados_ultimos_14dias': 15,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Santorcaz',
#    'codigo_geometria': '1369',
#    'tasa_incidencia_acumulada_ultimos_14dias': 564.334085778781,
#    'tasa_incidencia_acumulada_total': 4288.93905191874,
#    'casos_confirmados_totales': 38,
#    'casos_confirmados_ultimos_14dias': 5,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Coslada',
#    'codigo_geometria': '0493',
#    'tasa_incidencia_acumulada_ultimos_14dias': 258.385275713009,
#    'tasa_incidencia_acumulada_total': 5023.20569182351,
#    'casos_confirmados_totales': 4102,
#    'casos_confirmados_ultimos_14dias': 211,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Morata de Tajuña',
#    'codigo_geometria': '0915',
#    'tasa_incidencia_acumulada_ultimos_14dias': 494.598464141611,
#    'tasa_incidencia_acumulada_total': 6195.4965508265,
#    'casos_confirmados_totales': 476,
#    'casos_confirmados_ultimos_14dias': 38,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Robregordo',
#    'codigo_geometria': '1261',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 1724.13793103448,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Navarredonda y San Mamés',
#    'codigo_geometria': '0973',
#    'tasa_incidencia_acumulada_ultimos_14dias': 775.193798449612,
#    'tasa_incidencia_acumulada_total': 5426.35658914729,
#    'casos_confirmados_totales': 7,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Venturada',
#    'codigo_geometria': '1697',
#    'tasa_incidencia_acumulada_ultimos_14dias': 231.160425335183,
#    'tasa_incidencia_acumulada_total': 4299.5839112344,
#    'casos_confirmados_totales': 93,
#    'casos_confirmados_ultimos_14dias': 5,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Navacerrada',
#    'codigo_geometria': '0936',
#    'tasa_incidencia_acumulada_ultimos_14dias': 302.826379542396,
#    'tasa_incidencia_acumulada_total': 3600.26917900404,
#    'casos_confirmados_totales': 107,
#    'casos_confirmados_ultimos_14dias': 9,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Montejo de la Sierra',
#    'codigo_geometria': '0881',
#    'tasa_incidencia_acumulada_ultimos_14dias': 849.85835694051,
#    'tasa_incidencia_acumulada_total': 5099.15014164306,
#    'casos_confirmados_totales': 18,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Fresno de Torote',
#    'codigo_geometria': '0571',
#    'tasa_incidencia_acumulada_ultimos_14dias': 270.148581719946,
#    'tasa_incidencia_acumulada_total': 2656.46105357947,
#    'casos_confirmados_totales': 59,
#    'casos_confirmados_ultimos_14dias': 6,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Pinilla del Valle',
#    'codigo_geometria': '1126',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 523.560209424084,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdemaqueda',
#    'codigo_geometria': '1599',
#    'tasa_incidencia_acumulada_ultimos_14dias': 128.040973111396,
#    'tasa_incidencia_acumulada_total': 2816.9014084507,
#    'casos_confirmados_totales': 22,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Navas del Rey',
#    'codigo_geometria': '0992',
#    'tasa_incidencia_acumulada_ultimos_14dias': 137.080191912269,
#    'tasa_incidencia_acumulada_total': 4729.26662097327,
#    'casos_confirmados_totales': 138,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Olmeda de las Fuentes',
#    'codigo_geometria': '1013',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 2873.5632183908,
#    'casos_confirmados_totales': 10,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Bustarviejo',
#    'codigo_geometria': '0284',
#    'tasa_incidencia_acumulada_ultimos_14dias': 199.760287654814,
#    'tasa_incidencia_acumulada_total': 1558.13024370755,
#    'casos_confirmados_totales': 39,
#    'casos_confirmados_ultimos_14dias': 5,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Becerril de la Sierra',
#    'codigo_geometria': '0186',
#    'tasa_incidencia_acumulada_ultimos_14dias': 245.012250612531,
#    'tasa_incidencia_acumulada_total': 3290.16450822541,
#    'casos_confirmados_totales': 188,
#    'casos_confirmados_ultimos_14dias': 14,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Fuenlabrada',
#    'codigo_geometria': '0587',
#    'tasa_incidencia_acumulada_ultimos_14dias': 344.346928239546,
#    'tasa_incidencia_acumulada_total': 5433.14403717088,
#    'casos_confirmados_totales': 10524,
#    'casos_confirmados_ultimos_14dias': 667,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Garganta de los Montes',
#    'codigo_geometria': '0626',
#    'tasa_incidencia_acumulada_ultimos_14dias': 576.368876080692,
#    'tasa_incidencia_acumulada_total': 2305.47550432277,
#    'casos_confirmados_totales': 8,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Pinto',
#    'codigo_geometria': '1132',
#    'tasa_incidencia_acumulada_ultimos_14dias': 276.053763850284,
#    'tasa_incidencia_acumulada_total': 3849.52214141568,
#    'casos_confirmados_totales': 2022,
#    'casos_confirmados_ultimos_14dias': 145,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Alameda del Valle',
#    'codigo_geometria': '0035',
#    'tasa_incidencia_acumulada_ultimos_14dias': 500.0,
#    'tasa_incidencia_acumulada_total': 1000.0,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Berzosa del Lozoya',
#    'codigo_geometria': '0203',
#    'tasa_incidencia_acumulada_ultimos_14dias': 7804.87804878049,
#    'tasa_incidencia_acumulada_total': 18048.7804878049,
#    'casos_confirmados_totales': 37,
#    'casos_confirmados_ultimos_14dias': 16,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Los Santos de la Humosa',
#    'codigo_geometria': '1375',
#    'tasa_incidencia_acumulada_ultimos_14dias': 154.440154440154,
#    'tasa_incidencia_acumulada_total': 3011.58301158301,
#    'casos_confirmados_totales': 78,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'El Álamo',
#    'codigo_geometria': '0040',
#    'tasa_incidencia_acumulada_ultimos_14dias': 369.588173178458,
#    'tasa_incidencia_acumulada_total': 4065.46990496304,
#    'casos_confirmados_totales': 385,
#    'casos_confirmados_ultimos_14dias': 35,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Pelayos de la Presa',
#    'codigo_geometria': '1090',
#    'tasa_incidencia_acumulada_ultimos_14dias': 500.770416024653,
#    'tasa_incidencia_acumulada_total': 4776.57935285054,
#    'casos_confirmados_totales': 124,
#    'casos_confirmados_ultimos_14dias': 13,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Galapagar',
#    'codigo_geometria': '0611',
#    'tasa_incidencia_acumulada_ultimos_14dias': 444.549819216407,
#    'tasa_incidencia_acumulada_total': 4904.86633868769,
#    'casos_confirmados_totales': 1655,
#    'casos_confirmados_ultimos_14dias': 150,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Griñón',
#    'codigo_geometria': '0663',
#    'tasa_incidencia_acumulada_ultimos_14dias': 494.233937397035,
#    'tasa_incidencia_acumulada_total': 5552.86364957845,
#    'casos_confirmados_totales': 573,
#    'casos_confirmados_ultimos_14dias': 51,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Gargantilla del Lozoya y Pinilla de Buitrago',
#    'codigo_geometria': '0632',
#    'tasa_incidencia_acumulada_ultimos_14dias': 949.367088607595,
#    'tasa_incidencia_acumulada_total': 4746.83544303798,
#    'casos_confirmados_totales': 15,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Aldea del Fresno',
#    'codigo_geometria': '0088',
#    'tasa_incidencia_acumulada_ultimos_14dias': 211.416490486258,
#    'tasa_incidencia_acumulada_total': 4968.28752642706,
#    'casos_confirmados_totales': 141,
#    'casos_confirmados_ultimos_14dias': 6,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Carabaña',
#    'codigo_geometria': '0357',
#    'tasa_incidencia_acumulada_ultimos_14dias': 298.507462686567,
#    'tasa_incidencia_acumulada_total': 5422.8855721393,
#    'casos_confirmados_totales': 109,
#    'casos_confirmados_ultimos_14dias': 6,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Talamanca de Jarama',
#    'codigo_geometria': '1454',
#    'tasa_incidencia_acumulada_ultimos_14dias': 207.415089447757,
#    'tasa_incidencia_acumulada_total': 4640.91262639357,
#    'casos_confirmados_totales': 179,
#    'casos_confirmados_ultimos_14dias': 8,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Chapinería',
#    'codigo_geometria': '0513',
#    'tasa_incidencia_acumulada_ultimos_14dias': 85.9106529209622,
#    'tasa_incidencia_acumulada_total': 2534.36426116838,
#    'casos_confirmados_totales': 59,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Ciempozuelos',
#    'codigo_geometria': '0409',
#    'tasa_incidencia_acumulada_ultimos_14dias': 402.569941444372,
#    'tasa_incidencia_acumulada_total': 4363.20754716981,
#    'casos_confirmados_totales': 1073,
#    'casos_confirmados_ultimos_14dias': 99,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Ajalvir',
#    'codigo_geometria': '0029',
#    'tasa_incidencia_acumulada_ultimos_14dias': 212.224108658744,
#    'tasa_incidencia_acumulada_total': 2674.02376910017,
#    'casos_confirmados_totales': 126,
#    'casos_confirmados_ultimos_14dias': 10,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'San Lorenzo de El Escorial',
#    'codigo_geometria': '1317',
#    'tasa_incidencia_acumulada_ultimos_14dias': 261.309815449943,
#    'tasa_incidencia_acumulada_total': 3560.34623550547,
#    'casos_confirmados_totales': 654,
#    'casos_confirmados_ultimos_14dias': 48,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Gascones',
#    'codigo_geometria': '0647',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 1036.26943005181,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'San Martín de la Vega',
#    'codigo_geometria': '1322',
#    'tasa_incidencia_acumulada_ultimos_14dias': 349.504434011476,
#    'tasa_incidencia_acumulada_total': 4042.77516953573,
#    'casos_confirmados_totales': 775,
#    'casos_confirmados_ultimos_14dias': 67,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Móstoles',
#    'codigo_geometria': '0920',
#    'tasa_incidencia_acumulada_ultimos_14dias': 281.092244148692,
#    'tasa_incidencia_acumulada_total': 4556.27581459385,
#    'casos_confirmados_totales': 9531,
#    'casos_confirmados_ultimos_14dias': 588,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Leganés',
#    'codigo_geometria': '0745',
#    'tasa_incidencia_acumulada_ultimos_14dias': 233.855294136236,
#    'tasa_incidencia_acumulada_total': 4951.51716255576,
#    'casos_confirmados_totales': 9401,
#    'casos_confirmados_ultimos_14dias': 444,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Braojos',
#    'codigo_geometria': '0246',
#    'tasa_incidencia_acumulada_ultimos_14dias': 487.80487804878,
#    'tasa_incidencia_acumulada_total': 6829.26829268293,
#    'casos_confirmados_totales': 14,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Cubas de la Sagra',
#    'codigo_geometria': '0506',
#    'tasa_incidencia_acumulada_ultimos_14dias': 249.493216903165,
#    'tasa_incidencia_acumulada_total': 4849.52440355528,
#    'casos_confirmados_totales': 311,
#    'casos_confirmados_ultimos_14dias': 16,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Algete',
#    'codigo_geometria': '0091',
#    'tasa_incidencia_acumulada_ultimos_14dias': 349.328028722527,
#    'tasa_incidencia_acumulada_total': 4614.04104604338,
#    'casos_confirmados_totales': 951,
#    'casos_confirmados_ultimos_14dias': 72,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Mejorada del Campo',
#    'codigo_geometria': '0843',
#    'tasa_incidencia_acumulada_ultimos_14dias': 412.477442639856,
#    'tasa_incidencia_acumulada_total': 4459.91234854344,
#    'casos_confirmados_totales': 1038,
#    'casos_confirmados_ultimos_14dias': 96,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Loeches',
#    'codigo_geometria': '0758',
#    'tasa_incidencia_acumulada_ultimos_14dias': 261.631213741326,
#    'tasa_incidencia_acumulada_total': 3844.84131498123,
#    'casos_confirmados_totales': 338,
#    'casos_confirmados_ultimos_14dias': 23,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Parla',
#    'codigo_geometria': '1065',
#    'tasa_incidencia_acumulada_ultimos_14dias': 275.890688881375,
#    'tasa_incidencia_acumulada_total': 6102.64055823676,
#    'casos_confirmados_totales': 7941,
#    'casos_confirmados_ultimos_14dias': 359,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Fuentidueña de Tajo',
#    'codigo_geometria': '0604',
#    'tasa_incidencia_acumulada_ultimos_14dias': 779.347296639065,
#    'tasa_incidencia_acumulada_total': 5845.10472479299,
#    'casos_confirmados_totales': 120,
#    'casos_confirmados_ultimos_14dias': 16,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Ambite',
#    'codigo_geometria': '0112',
#    'tasa_incidencia_acumulada_ultimos_14dias': 675.675675675676,
#    'tasa_incidencia_acumulada_total': 5574.32432432432,
#    'casos_confirmados_totales': 33,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Torremocha de Jarama',
#    'codigo_geometria': '1533',
#    'tasa_incidencia_acumulada_ultimos_14dias': 196.270853778214,
#    'tasa_incidencia_acumulada_total': 3532.87536800785,
#    'casos_confirmados_totales': 36,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Anchuelo',
#    'codigo_geometria': '0127',
#    'tasa_incidencia_acumulada_ultimos_14dias': 472.0692368214,
#    'tasa_incidencia_acumulada_total': 2517.7025963808,
#    'casos_confirmados_totales': 32,
#    'casos_confirmados_ultimos_14dias': 6,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Los Molinos',
#    'codigo_geometria': '0875',
#    'tasa_incidencia_acumulada_ultimos_14dias': 182.273866484393,
#    'tasa_incidencia_acumulada_total': 5354.29482797904,
#    'casos_confirmados_totales': 235,
#    'casos_confirmados_ultimos_14dias': 8,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Soto del Real',
#    'codigo_geometria': '1441',
#    'tasa_incidencia_acumulada_ultimos_14dias': 193.20377315604,
#    'tasa_incidencia_acumulada_total': 2648.02818502102,
#    'casos_confirmados_totales': 233,
#    'casos_confirmados_ultimos_14dias': 17,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valverde de Alcalá',
#    'codigo_geometria': '1662',
#    'tasa_incidencia_acumulada_ultimos_14dias': 215.05376344086,
#    'tasa_incidencia_acumulada_total': 3870.96774193548,
#    'casos_confirmados_totales': 18,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Fuente el Saz de Jarama',
#    'codigo_geometria': '0590',
#    'tasa_incidencia_acumulada_ultimos_14dias': 134.408602150538,
#    'tasa_incidencia_acumulada_total': 5167.26403823178,
#    'casos_confirmados_totales': 346,
#    'casos_confirmados_ultimos_14dias': 9,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Horcajo de la Sierra-Aoslos',
#    'codigo_geometria': '0702',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 4137.93103448276,
#    'casos_confirmados_totales': 6,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdeolmos-Alalpardo',
#    'codigo_geometria': '1625',
#    'tasa_incidencia_acumulada_ultimos_14dias': 169.245647969052,
#    'tasa_incidencia_acumulada_total': 3650.87040618956,
#    'casos_confirmados_totales': 151,
#    'casos_confirmados_ultimos_14dias': 7,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Campo Real',
#    'codigo_geometria': '0339',
#    'tasa_incidencia_acumulada_ultimos_14dias': 273.752012882448,
#    'tasa_incidencia_acumulada_total': 5136.87600644122,
#    'casos_confirmados_totales': 319,
#    'casos_confirmados_ultimos_14dias': 17,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdeavero',
#    'codigo_geometria': '1564',
#    'tasa_incidencia_acumulada_ultimos_14dias': 193.050193050193,
#    'tasa_incidencia_acumulada_total': 1994.85199485199,
#    'casos_confirmados_totales': 31,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Villamanrique de Tajo',
#    'codigo_geometria': '1739',
#    'tasa_incidencia_acumulada_ultimos_14dias': 284.495021337127,
#    'tasa_incidencia_acumulada_total': 3271.69274537696,
#    'casos_confirmados_totales': 23,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Cobeña',
#    'codigo_geometria': '0416',
#    'tasa_incidencia_acumulada_ultimos_14dias': 228.863758750673,
#    'tasa_incidencia_acumulada_total': 4456.11200861605,
#    'casos_confirmados_totales': 331,
#    'casos_confirmados_ultimos_14dias': 17,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Fresnedillas de la Oliva',
#    'codigo_geometria': '0565',
#    'tasa_incidencia_acumulada_ultimos_14dias': 190.839694656489,
#    'tasa_incidencia_acumulada_total': 2862.59541984733,
#    'casos_confirmados_totales': 45,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdilecha',
#    'codigo_geometria': '1659',
#    'tasa_incidencia_acumulada_ultimos_14dias': 886.464370951244,
#    'tasa_incidencia_acumulada_total': 6205.25059665871,
#    'casos_confirmados_totales': 182,
#    'casos_confirmados_ultimos_14dias': 26,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'El Berrueco',
#    'codigo_geometria': '0210',
#    'tasa_incidencia_acumulada_ultimos_14dias': 526.315789473684,
#    'tasa_incidencia_acumulada_total': 6973.68421052631,
#    'casos_confirmados_totales': 53,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Pezuela de las Torres',
#    'codigo_geometria': '1111',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 2731.59144893112,
#    'casos_confirmados_totales': 23,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Villar del Olmo',
#    'codigo_geometria': '1795',
#    'tasa_incidencia_acumulada_ultimos_14dias': 149.179512680259,
#    'tasa_incidencia_acumulada_total': 2983.59025360517,
#    'casos_confirmados_totales': 60,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Guadarrama',
#    'codigo_geometria': '0685',
#    'tasa_incidencia_acumulada_ultimos_14dias': 424.151696606786,
#    'tasa_incidencia_acumulada_total': 4996.25748502994,
#    'casos_confirmados_totales': 801,
#    'casos_confirmados_ultimos_14dias': 68,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'San Martín de Valdeiglesias',
#    'codigo_geometria': '1338',
#    'tasa_incidencia_acumulada_ultimos_14dias': 413.760491783899,
#    'tasa_incidencia_acumulada_total': 4906.01725972337,
#    'casos_confirmados_totales': 415,
#    'casos_confirmados_ultimos_14dias': 35,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Torrelodones',
#    'codigo_geometria': '1527',
#    'tasa_incidencia_acumulada_ultimos_14dias': 295.146941012776,
#    'tasa_incidencia_acumulada_total': 3950.75262469958,
#    'casos_confirmados_totales': 937,
#    'casos_confirmados_ultimos_14dias': 70,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Boadilla del Monte',
#    'codigo_geometria': '0225',
#    'tasa_incidencia_acumulada_ultimos_14dias': 364.669232178853,
#    'tasa_incidencia_acumulada_total': 3084.11214953271,
#    'casos_confirmados_totales': 1683,
#    'casos_confirmados_ultimos_14dias': 199,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Torrejón de Velasco',
#    'codigo_geometria': '1505',
#    'tasa_incidencia_acumulada_ultimos_14dias': 273.847558192606,
#    'tasa_incidencia_acumulada_total': 4244.63715198539,
#    'casos_confirmados_totales': 186,
#    'casos_confirmados_ultimos_14dias': 12,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Villanueva de Perales',
#    'codigo_geometria': '1782',
#    'tasa_incidencia_acumulada_ultimos_14dias': 191.938579654511,
#    'tasa_incidencia_acumulada_total': 1791.4267434421,
#    'casos_confirmados_totales': 28,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Tielmes',
#    'codigo_geometria': '1467',
#    'tasa_incidencia_acumulada_ultimos_14dias': 566.037735849057,
#    'tasa_incidencia_acumulada_total': 6981.1320754717,
#    'casos_confirmados_totales': 185,
#    'casos_confirmados_ultimos_14dias': 15,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'San Sebastián de los Reyes',
#    'codigo_geometria': '1343',
#    'tasa_incidencia_acumulada_ultimos_14dias': 305.79327030781,
#    'tasa_incidencia_acumulada_total': 4841.16671893902,
#    'casos_confirmados_totales': 4322,
#    'casos_confirmados_ultimos_14dias': 273,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Guadalix de la Sierra',
#    'codigo_geometria': '0679',
#    'tasa_incidencia_acumulada_ultimos_14dias': 370.131960090119,
#    'tasa_incidencia_acumulada_total': 3797.87576440296,
#    'casos_confirmados_totales': 236,
#    'casos_confirmados_ultimos_14dias': 23,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Humanes de Madrid',
#    'codigo_geometria': '0730',
#    'tasa_incidencia_acumulada_ultimos_14dias': 334.295699741681,
#    'tasa_incidencia_acumulada_total': 5875.50017727802,
#    'casos_confirmados_totales': 1160,
#    'casos_confirmados_ultimos_14dias': 66,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Chinchón',
#    'codigo_geometria': '0528',
#    'tasa_incidencia_acumulada_ultimos_14dias': 525.229788032264,
#    'tasa_incidencia_acumulada_total': 4126.80547739636,
#    'casos_confirmados_totales': 220,
#    'casos_confirmados_ultimos_14dias': 28,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Cadalso de los Vidrios',
#    'codigo_geometria': '0318',
#    'tasa_incidencia_acumulada_ultimos_14dias': 427.772293517604,
#    'tasa_incidencia_acumulada_total': 2632.44488318526,
#    'casos_confirmados_totales': 80,
#    'casos_confirmados_ultimos_14dias': 13,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Hoyo de Manzanares',
#    'codigo_geometria': '0724',
#    'tasa_incidencia_acumulada_ultimos_14dias': 296.41925539483,
#    'tasa_incidencia_acumulada_total': 3118.33056675362,
#    'casos_confirmados_totales': 263,
#    'casos_confirmados_ultimos_14dias': 25,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Torrejón de la Calzada',
#    'codigo_geometria': '1492',
#    'tasa_incidencia_acumulada_ultimos_14dias': 371.956717763751,
#    'tasa_incidencia_acumulada_total': 4440.93778178539,
#    'casos_confirmados_totales': 394,
#    'casos_confirmados_ultimos_14dias': 33,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Estremera',
#    'codigo_geometria': '0552',
#    'tasa_incidencia_acumulada_ultimos_14dias': 158.730158730159,
#    'tasa_incidencia_acumulada_total': 3650.79365079365,
#    'casos_confirmados_totales': 46,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Corpa',
#    'codigo_geometria': '0480',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 2244.03927068724,
#    'casos_confirmados_totales': 16,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Meco',
#    'codigo_geometria': '0838',
#    'tasa_incidencia_acumulada_ultimos_14dias': 209.716882209018,
#    'tasa_incidencia_acumulada_total': 3068.85704299196,
#    'casos_confirmados_totales': 439,
#    'casos_confirmados_ultimos_14dias': 30,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Madarcos',
#    'codigo_geometria': '0783',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 8333.33333333333,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Zarzalejo',
#    'codigo_geometria': '1837',
#    'tasa_incidencia_acumulada_ultimos_14dias': 60.313630880579,
#    'tasa_incidencia_acumulada_total': 4644.14957780458,
#    'casos_confirmados_totales': 77,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Arganda del Rey',
#    'codigo_geometria': '0148',
#    'tasa_incidencia_acumulada_ultimos_14dias': 330.390510751232,
#    'tasa_incidencia_acumulada_total': 4670.60246619365,
#    'casos_confirmados_totales': 2587,
#    'casos_confirmados_ultimos_14dias': 183,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Collado Mediano',
#    'codigo_geometria': '0468',
#    'tasa_incidencia_acumulada_ultimos_14dias': 416.786432883012,
#    'tasa_incidencia_acumulada_total': 3133.08421960333,
#    'casos_confirmados_totales': 218,
#    'casos_confirmados_ultimos_14dias': 29,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Daganzo de Arriba',
#    'codigo_geometria': '0534',
#    'tasa_incidencia_acumulada_ultimos_14dias': 88.1920627143557,
#    'tasa_incidencia_acumulada_total': 2969.13277804998,
#    'casos_confirmados_totales': 303,
#    'casos_confirmados_ultimos_14dias': 9,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Manzanares El Real',
#    'codigo_geometria': '0822',
#    'tasa_incidencia_acumulada_ultimos_14dias': 339.366515837104,
#    'tasa_incidencia_acumulada_total': 3687.78280542986,
#    'casos_confirmados_totales': 326,
#    'casos_confirmados_ultimos_14dias': 30,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Buitrago del Lozoya',
#    'codigo_geometria': '0278',
#    'tasa_incidencia_acumulada_ultimos_14dias': 265.392781316348,
#    'tasa_incidencia_acumulada_total': 4299.36305732484,
#    'casos_confirmados_totales': 81,
#    'casos_confirmados_ultimos_14dias': 5,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdelaguna',
#    'codigo_geometria': '1570',
#    'tasa_incidencia_acumulada_ultimos_14dias': 320.17075773746,
#    'tasa_incidencia_acumulada_total': 3521.87833511206,
#    'casos_confirmados_totales': 33,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdepiélagos',
#    'codigo_geometria': '1631',
#    'tasa_incidencia_acumulada_ultimos_14dias': 1027.39726027397,
#    'tasa_incidencia_acumulada_total': 4280.82191780822,
#    'casos_confirmados_totales': 25,
#    'casos_confirmados_ultimos_14dias': 6,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Casarrubuelos',
#    'codigo_geometria': '0360',
#    'tasa_incidencia_acumulada_ultimos_14dias': 291.159343568025,
#    'tasa_incidencia_acumulada_total': 4314.45209105347,
#    'casos_confirmados_totales': 163,
#    'casos_confirmados_ultimos_14dias': 11,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Miraflores de la Sierra',
#    'codigo_geometria': '0856',
#    'tasa_incidencia_acumulada_ultimos_14dias': 360.183366077276,
#    'tasa_incidencia_acumulada_total': 3077.93058284217,
#    'casos_confirmados_totales': 188,
#    'casos_confirmados_ultimos_14dias': 22,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Paracuellos de Jarama',
#    'codigo_geometria': '1049',
#    'tasa_incidencia_acumulada_ultimos_14dias': 154.339309034786,
#    'tasa_incidencia_acumulada_total': 3332.14610787922,
#    'casos_confirmados_totales': 842,
#    'casos_confirmados_ultimos_14dias': 39,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'El Vellón',
#    'codigo_geometria': '1684',
#    'tasa_incidencia_acumulada_ultimos_14dias': 102.145045965271,
#    'tasa_incidencia_acumulada_total': 4902.96220633299,
#    'casos_confirmados_totales': 96,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Lozoya',
#    'codigo_geometria': '0761',
#    'tasa_incidencia_acumulada_ultimos_14dias': 344.234079173838,
#    'tasa_incidencia_acumulada_total': 2581.75559380379,
#    'casos_confirmados_totales': 15,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Collado Villalba',
#    'codigo_geometria': '0474',
#    'tasa_incidencia_acumulada_ultimos_14dias': 406.727492579971,
#    'tasa_incidencia_acumulada_total': 5014.21190659401,
#    'casos_confirmados_totales': 3193,
#    'casos_confirmados_ultimos_14dias': 259,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Colmenarejo',
#    'codigo_geometria': '0442',
#    'tasa_incidencia_acumulada_ultimos_14dias': 186.199342825849,
#    'tasa_incidencia_acumulada_total': 3274.91785323111,
#    'casos_confirmados_totales': 299,
#    'casos_confirmados_ultimos_14dias': 17,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Villavieja del Lozoya',
#    'codigo_geometria': '1821',
#    'tasa_incidencia_acumulada_ultimos_14dias': 1976.28458498024,
#    'tasa_incidencia_acumulada_total': 3162.05533596838,
#    'casos_confirmados_totales': 8,
#    'casos_confirmados_ultimos_14dias': 5,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Prádena del Rincón',
#    'codigo_geometria': '1179',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 854.700854700855,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'La Cabrera',
#    'codigo_geometria': '0301',
#    'tasa_incidencia_acumulada_ultimos_14dias': 187.476565429321,
#    'tasa_incidencia_acumulada_total': 4686.91413573303,
#    'casos_confirmados_totales': 125,
#    'casos_confirmados_ultimos_14dias': 5,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Sevilla la Nueva',
#    'codigo_geometria': '1415',
#    'tasa_incidencia_acumulada_ultimos_14dias': 257.56600128783,
#    'tasa_incidencia_acumulada_total': 3992.27301996136,
#    'casos_confirmados_totales': 372,
#    'casos_confirmados_ultimos_14dias': 24,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'La Acebeda',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 0.0,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Redueña',
#    'codigo_geometria': '1219',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 2307.69230769231,
#    'casos_confirmados_totales': 6,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Robledillo de la Jara',
#    'codigo_geometria': '1245',
#    'tasa_incidencia_acumulada_ultimos_14dias': 1250.0,
#    'tasa_incidencia_acumulada_total': 11250.0,
#    'casos_confirmados_totales': 9,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'La Serna del Monte',
#    'codigo_geometria': '1381',
#    'tasa_incidencia_acumulada_ultimos_14dias': 1234.56790123457,
#    'tasa_incidencia_acumulada_total': 6172.83950617284,
#    'casos_confirmados_totales': 5,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Colmenar de Oreja',
#    'codigo_geometria': '0437',
#    'tasa_incidencia_acumulada_ultimos_14dias': 946.215139442231,
#    'tasa_incidencia_acumulada_total': 4668.82470119522,
#    'casos_confirmados_totales': 375,
#    'casos_confirmados_ultimos_14dias': 76,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Rozas de Puerto Real',
#    'codigo_geometria': '1283',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 3773.58490566038,
#    'casos_confirmados_totales': 20,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdemanco',
#    'codigo_geometria': '1586',
#    'tasa_incidencia_acumulada_ultimos_14dias': 109.409190371991,
#    'tasa_incidencia_acumulada_total': 2297.59299781182,
#    'casos_confirmados_totales': 21,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Brunete',
#    'codigo_geometria': '0262',
#    'tasa_incidencia_acumulada_ultimos_14dias': 316.691505216095,
#    'tasa_incidencia_acumulada_total': 3464.97764530551,
#    'casos_confirmados_totales': 372,
#    'casos_confirmados_ultimos_14dias': 34,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Titulcia',
#    'codigo_geometria': '1473',
#    'tasa_incidencia_acumulada_ultimos_14dias': 152.322924600152,
#    'tasa_incidencia_acumulada_total': 2665.65118050267,
#    'casos_confirmados_totales': 35,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Villa del Prado',
#    'codigo_geometria': '1718',
#    'tasa_incidencia_acumulada_ultimos_14dias': 368.098159509202,
#    'tasa_incidencia_acumulada_total': 7622.69938650307,
#    'casos_confirmados_totales': 497,
#    'casos_confirmados_ultimos_14dias': 24,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Lozoyuela-Navas-Sieteiglesias',
#    'codigo_geometria': '9015',
#    'tasa_incidencia_acumulada_ultimos_14dias': 230.94688221709,
#    'tasa_incidencia_acumulada_total': 3387.22093918399,
#    'casos_confirmados_totales': 44,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Quijorna',
#    'codigo_geometria': '1198',
#    'tasa_incidencia_acumulada_ultimos_14dias': 348.938644954929,
#    'tasa_incidencia_acumulada_total': 3692.93399243966,
#    'casos_confirmados_totales': 127,
#    'casos_confirmados_ultimos_14dias': 12,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Valdemoro',
#    'codigo_geometria': '1610',
#    'tasa_incidencia_acumulada_ultimos_14dias': 206.625166155587,
#    'tasa_incidencia_acumulada_total': 3448.13971546267,
#    'casos_confirmados_totales': 2620,
#    'casos_confirmados_ultimos_14dias': 157,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Tres Cantos',
#    'codigo_geometria': '9036',
#    'tasa_incidencia_acumulada_ultimos_14dias': 232.597125015716,
#    'tasa_incidencia_acumulada_total': 3134.82251372533,
#    'casos_confirmados_totales': 1496,
#    'casos_confirmados_ultimos_14dias': 111,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Torrelaguna',
#    'codigo_geometria': '1512',
#    'tasa_incidencia_acumulada_ultimos_14dias': 441.176470588235,
#    'tasa_incidencia_acumulada_total': 5525.21008403361,
#    'casos_confirmados_totales': 263,
#    'casos_confirmados_ultimos_14dias': 21,
#    'fecha_informe': '2020/11/17 12:22:00'},
#   {'municipio_distrito': 'Rivas-Vaciamadrid',
#    'codigo_geometria': '1230',
# ...
#    'tasa_incidencia_acumulada_total': 2785.02,
#    'casos_confirmados_totales': 299,
#    'casos_confirmados_ultimos_14dias': 34,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Titulcia',
#    'codigo_geometria': '1473',
#    'tasa_incidencia_acumulada_ultimos_14dias': 456.97,
#    'tasa_incidencia_acumulada_total': 1904.04,
#    'casos_confirmados_totales': 25,
#    'casos_confirmados_ultimos_14dias': 6,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Villa del Prado',
#    'codigo_geometria': '1718',
#    'tasa_incidencia_acumulada_ultimos_14dias': 76.69,
#    'tasa_incidencia_acumulada_total': 6886.5,
#    'casos_confirmados_totales': 449,
#    'casos_confirmados_ultimos_14dias': 5,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Lozoyuela-Navas-Sieteiglesias',
#    'codigo_geometria': '9015',
#    'tasa_incidencia_acumulada_ultimos_14dias': 692.84,
#    'tasa_incidencia_acumulada_total': 2463.43,
#    'casos_confirmados_totales': 32,
#    'casos_confirmados_ultimos_14dias': 9,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Quijorna',
#    'codigo_geometria': '1198',
#    'tasa_incidencia_acumulada_ultimos_14dias': 436.17,
#    'tasa_incidencia_acumulada_total': 2791.51,
#    'casos_confirmados_totales': 96,
#    'casos_confirmados_ultimos_14dias': 15,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Valdemoro',
#    'codigo_geometria': '1610',
#    'tasa_incidencia_acumulada_ultimos_14dias': 315.86,
#    'tasa_incidencia_acumulada_total': 2876.96,
#    'casos_confirmados_totales': 2186,
#    'casos_confirmados_ultimos_14dias': 240,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Tres Cantos',
#    'codigo_geometria': '9036',
#    'tasa_incidencia_acumulada_ultimos_14dias': 301.75,
#    'tasa_incidencia_acumulada_total': 2562.76,
#    'casos_confirmados_totales': 1223,
#    'casos_confirmados_ultimos_14dias': 144,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Torrelaguna',
#    'codigo_geometria': '1512',
#    'tasa_incidencia_acumulada_ultimos_14dias': 483.19,
#    'tasa_incidencia_acumulada_total': 4600.84,
#    'casos_confirmados_totales': 219,
#    'casos_confirmados_ultimos_14dias': 23,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Rivas-Vaciamadrid',
#    'codigo_geometria': '1230',
#    'tasa_incidencia_acumulada_ultimos_14dias': 349.4,
#    'tasa_incidencia_acumulada_total': 3246.74,
#    'casos_confirmados_totales': 2862,
#    'casos_confirmados_ultimos_14dias': 308,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'El Atazar',
#    'codigo_geometria': '164',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 1123.6,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Pedrezuela',
#    'codigo_geometria': '1087',
#    'tasa_incidencia_acumulada_ultimos_14dias': 271.55,
#    'tasa_incidencia_acumulada_total': 2800.41,
#    'casos_confirmados_totales': 165,
#    'casos_confirmados_ultimos_14dias': 16,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Santa María de la Alameda',
#    'codigo_geometria': '1356',
#    'tasa_incidencia_acumulada_ultimos_14dias': 159.49,
#    'tasa_incidencia_acumulada_total': 2392.34,
#    'casos_confirmados_totales': 30,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Arroyomolinos',
#    'codigo_geometria': '151',
#    'tasa_incidencia_acumulada_ultimos_14dias': 350.36,
#    'tasa_incidencia_acumulada_total': 2478.02,
#    'casos_confirmados_totales': 778,
#    'casos_confirmados_ultimos_14dias': 110,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Moralzarzal',
#    'codigo_geometria': '908',
#    'tasa_incidencia_acumulada_ultimos_14dias': 345.46,
#    'tasa_incidencia_acumulada_total': 2571.78,
#    'casos_confirmados_totales': 335,
#    'casos_confirmados_ultimos_14dias': 45,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Canencia',
#    'codigo_geometria': '344',
#    'tasa_incidencia_acumulada_ultimos_14dias': 447.43,
#    'tasa_incidencia_acumulada_total': 3803.13,
#    'casos_confirmados_totales': 17,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Villarejo de Salvanés',
#    'codigo_geometria': '1809',
#    'tasa_incidencia_acumulada_ultimos_14dias': 708.93,
#    'tasa_incidencia_acumulada_total': 3967.28,
#    'casos_confirmados_totales': 291,
#    'casos_confirmados_ultimos_14dias': 52,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Serranillos del Valle',
#    'codigo_geometria': '1408',
#    'tasa_incidencia_acumulada_ultimos_14dias': 480.19,
#    'tasa_incidencia_acumulada_total': 3937.58,
#    'casos_confirmados_totales': 164,
#    'casos_confirmados_ultimos_14dias': 20,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Villaviciosa de Odón',
#    'codigo_geometria': '1816',
#    'tasa_incidencia_acumulada_ultimos_14dias': 308.96,
#    'tasa_incidencia_acumulada_total': 2493.26,
#    'casos_confirmados_totales': 694,
#    'casos_confirmados_ultimos_14dias': 86,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Camarma de Esteruelas',
#    'codigo_geometria': '323',
#    'tasa_incidencia_acumulada_ultimos_14dias': 204.47,
#    'tasa_incidencia_acumulada_total': 1867.5,
#    'casos_confirmados_totales': 137,
#    'casos_confirmados_ultimos_14dias': 15,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Robledo de Chavela',
#    'codigo_geometria': '1258',
#    'tasa_incidencia_acumulada_ultimos_14dias': 257.61,
#    'tasa_incidencia_acumulada_total': 2201.41,
#    'casos_confirmados_totales': 94,
#    'casos_confirmados_ultimos_14dias': 11,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Patones',
#    'codigo_geometria': '1071',
#    'tasa_incidencia_acumulada_ultimos_14dias': 184.84,
#    'tasa_incidencia_acumulada_total': 4990.76,
#    'casos_confirmados_totales': 27,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Navalagamella',
#    'codigo_geometria': '954',
#    'tasa_incidencia_acumulada_ultimos_14dias': 421.46,
#    'tasa_incidencia_acumulada_total': 3716.48,
#    'casos_confirmados_totales': 97,
#    'casos_confirmados_ultimos_14dias': 11,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Rascafría',
#    'codigo_geometria': '1202',
#    'tasa_incidencia_acumulada_ultimos_14dias': 300.48,
#    'tasa_incidencia_acumulada_total': 2584.13,
#    'casos_confirmados_totales': 43,
#    'casos_confirmados_ultimos_14dias': 5,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'El Boalo',
#    'codigo_geometria': '231',
#    'tasa_incidencia_acumulada_ultimos_14dias': 652.64,
#    'tasa_incidencia_acumulada_total': 3169.95,
#    'casos_confirmados_totales': 238,
#    'casos_confirmados_ultimos_14dias': 49,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Majadahonda',
#    'codigo_geometria': '800',
#    'tasa_incidencia_acumulada_ultimos_14dias': 744.86,
#    'tasa_incidencia_acumulada_total': 3972.1,
#    'casos_confirmados_totales': 2853,
#    'casos_confirmados_ultimos_14dias': 535,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Batres',
#    'codigo_geometria': '170',
#    'tasa_incidencia_acumulada_ultimos_14dias': 296.91,
#    'tasa_incidencia_acumulada_total': 2315.91,
#    'casos_confirmados_totales': 39,
#    'casos_confirmados_ultimos_14dias': 5,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Alcobendas',
#    'codigo_geometria': '66',
#    'tasa_incidencia_acumulada_ultimos_14dias': 322.97,
#    'tasa_incidencia_acumulada_total': 5005.13,
#    'casos_confirmados_totales': 5858,
#    'casos_confirmados_ultimos_14dias': 378,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Alcalá de Henares',
#    'codigo_geometria': '53',
#    'tasa_incidencia_acumulada_ultimos_14dias': 314.34,
#    'tasa_incidencia_acumulada_total': 3436.26,
#    'casos_confirmados_totales': 6723,
#    'casos_confirmados_ultimos_14dias': 615,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Colmenar Viejo',
#    'codigo_geometria': '455',
#    'tasa_incidencia_acumulada_ultimos_14dias': 526.09,
#    'tasa_incidencia_acumulada_total': 3932.85,
#    'casos_confirmados_totales': 1996,
#    'casos_confirmados_ultimos_14dias': 267,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'San Fernando de Henares',
#    'codigo_geometria': '1300',
#    'tasa_incidencia_acumulada_ultimos_14dias': 327.15,
#    'tasa_incidencia_acumulada_total': 3826.84,
#    'casos_confirmados_totales': 1509,
#    'casos_confirmados_ultimos_14dias': 129,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Villalbilla',
#    'codigo_geometria': '1723',
#    'tasa_incidencia_acumulada_ultimos_14dias': 237.79,
#    'tasa_incidencia_acumulada_total': 2183.31,
#    'casos_confirmados_totales': 303,
#    'casos_confirmados_ultimos_14dias': 33,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'El Escorial',
#    'codigo_geometria': '549',
#    'tasa_incidencia_acumulada_ultimos_14dias': 358.87,
#    'tasa_incidencia_acumulada_total': 2809.06,
#    'casos_confirmados_totales': 454,
#    'casos_confirmados_ultimos_14dias': 58,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Colmenar del Arroyo',
#    'codigo_geometria': '421',
#    'tasa_incidencia_acumulada_ultimos_14dias': 231.88,
#    'tasa_incidencia_acumulada_total': 5449.28,
#    'casos_confirmados_totales': 94,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Torrejón de Ardoz',
#    'codigo_geometria': '1489',
#    'tasa_incidencia_acumulada_ultimos_14dias': 455.94,
#    'tasa_incidencia_acumulada_total': 4542.69,
#    'casos_confirmados_totales': 5968,
#    'casos_confirmados_ultimos_14dias': 599,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Piñuécar-Gandullas',
#    'codigo_geometria': '1147',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 1621.62,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Brea de Tajo',
#    'codigo_geometria': '259',
#    'tasa_incidencia_acumulada_ultimos_14dias': 381.68,
#    'tasa_incidencia_acumulada_total': 5152.67,
#    'casos_confirmados_totales': 27,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'El Molar',
#    'codigo_geometria': '869',
#    'tasa_incidencia_acumulada_ultimos_14dias': 648.91,
#    'tasa_incidencia_acumulada_total': 3087.94,
#    'casos_confirmados_totales': 276,
#    'casos_confirmados_ultimos_14dias': 58,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Belmonte de Tajo',
#    'codigo_geometria': '199',
#    'tasa_incidencia_acumulada_ultimos_14dias': 540.87,
#    'tasa_incidencia_acumulada_total': 2163.46,
#    'casos_confirmados_totales': 36,
#    'casos_confirmados_ultimos_14dias': 9,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Torres de la Alameda',
#    'codigo_geometria': '1548',
#    'tasa_incidencia_acumulada_ultimos_14dias': 449.93,
#    'tasa_incidencia_acumulada_total': 3612.29,
#    'casos_confirmados_totales': 281,
#    'casos_confirmados_ultimos_14dias': 35,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Somosierra',
#    'codigo_geometria': '1436',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 2325.58,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Alpedrete',
#    'codigo_geometria': '105',
#    'tasa_incidencia_acumulada_ultimos_14dias': 473.41,
#    'tasa_incidencia_acumulada_total': 3142.37,
#    'casos_confirmados_totales': 458,
#    'casos_confirmados_ultimos_14dias': 69,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Orusco de Tajuña',
#    'codigo_geometria': '1028',
#    'tasa_incidencia_acumulada_ultimos_14dias': 482.32,
#    'tasa_incidencia_acumulada_total': 4501.61,
#    'casos_confirmados_totales': 56,
#    'casos_confirmados_ultimos_14dias': 6,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'La Hiruela',
#    'codigo_geometria': '698',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 3508.77,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Cervera de Buitrago',
#    'codigo_geometria': '395',
#    'tasa_incidencia_acumulada_ultimos_14dias': 2000.0,
#    'tasa_incidencia_acumulada_total': 6000.0,
#    'casos_confirmados_totales': 9,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Getafe',
#    'codigo_geometria': '650',
#    'tasa_incidencia_acumulada_ultimos_14dias': 331.02,
#    'tasa_incidencia_acumulada_total': 4014.2,
#    'casos_confirmados_totales': 7361,
#    'casos_confirmados_ultimos_14dias': 607,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Ribatejada',
#    'codigo_geometria': '1224',
#    'tasa_incidencia_acumulada_ultimos_14dias': 127.71,
#    'tasa_incidencia_acumulada_total': 2171.14,
#    'casos_confirmados_totales': 17,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Villaconejos',
#    'codigo_geometria': '1701',
#    'tasa_incidencia_acumulada_ultimos_14dias': 236.13,
#    'tasa_incidencia_acumulada_total': 3305.79,
#    'casos_confirmados_totales': 112,
#    'casos_confirmados_ultimos_14dias': 8,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Valdetorres de Jarama',
#    'codigo_geometria': '1646',
#    'tasa_incidencia_acumulada_ultimos_14dias': 244.61,
#    'tasa_incidencia_acumulada_total': 2090.28,
#    'casos_confirmados_totales': 94,
#    'casos_confirmados_ultimos_14dias': 11,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Puebla de la Sierra',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 0.0,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'La Acebeda',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 0.0,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Horcajuelo de la Sierra',
#    'tasa_incidencia_acumulada_ultimos_14dias': 0.0,
#    'tasa_incidencia_acumulada_total': 0.0,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Pozuelo de Alarcón',
#    'codigo_geometria': '1150',
#    'tasa_incidencia_acumulada_ultimos_14dias': 440.86,
#    'tasa_incidencia_acumulada_total': 3408.85,
#    'casos_confirmados_totales': 2946,
#    'casos_confirmados_ultimos_14dias': 381,
#    'fecha_informe': '2020/10/20 11:06:00'},
#   {'municipio_distrito': 'Madrid-Retiro',
#    'codigo_geometria': '79603',
#    'tasa_incidencia_acumulada_ultimos_14dias': 383.01,
#    'tasa_incidencia_acumulada_total': 3793.26,
#    'casos_confirmados_totales': 4526,
#    'casos_confirmados_ultimos_14dias': 457,
#    'fecha_informe': '2020/10/13 13:31:00'},
#   {'municipio_distrito': 'Madrid-Salamanca',
#    'codigo_geometria': '79604',
#    'tasa_incidencia_acumulada_ultimos_14dias': 377.81,
#    'tasa_incidencia_acumulada_total': 3726.11,
#    'casos_confirmados_totales': 5444,
#    'casos_confirmados_ultimos_14dias': 552,
#    'fecha_informe': '2020/10/13 13:31:00'},
#   {'municipio_distrito': 'Madrid-Centro',
#    'codigo_geometria': '79601',
#    'tasa_incidencia_acumulada_ultimos_14dias': 440.5,
#    'tasa_incidencia_acumulada_total': 4084.6,
#    'casos_confirmados_totales': 5508,
#    'casos_confirmados_ultimos_14dias': 594,
#    'fecha_informe': '2020/10/13 13:31:00'},
#   {'municipio_distrito': 'Madrid-Arganzuela',
#    'codigo_geometria': '79602',
#    'tasa_incidencia_acumulada_ultimos_14dias': 451.88,
#    'tasa_incidencia_acumulada_total': 3945.96,
#    'casos_confirmados_totales': 6069,
#    'casos_confirmados_ultimos_14dias': 695,
#    'fecha_informe': '2020/10/13 13:31:00'},
#   {'municipio_distrito': 'Madrid-Chamartín',
#    'codigo_geometria': '79605',
#    'tasa_incidencia_acumulada_ultimos_14dias': 357.22,
#    'tasa_incidencia_acumulada_total': 3538.59,
#    'casos_confirmados_totales': 5161,
#    'casos_confirmados_ultimos_14dias': 521,
#    'fecha_informe': '2020/10/13 13:31:00'},
#   ...]}

# %% [markdown]
# ### Formato yaml

# %% [markdown]
# YAML es un formato para guardar objetos de datos con estructura de árbol. Sus siglas significan YAML Ain’t Markup Language. Este lenguaje es muy legible para las personas, más legible que un JSON y sobretodo que XML. Se utiliza normalmente para: archivos de configuración, traducciones y para representar información. Sus ventajas frente al formato JSON/XML:
# - es un formato mucho más amigable
# - fácil de entender rápidamente
# - facilita el mapeo de estructuras de datos complejas.

# %% [markdown]
# YAML usa tres guiones (“ ---”) para indicar el comienzo de un documento y tres puntos (“ ...”) para indicar el final de un documento. A diferencia de JSON, YAML usa las sangrías como en Python para mostrar los niveles en los datos. Los pares clave / valor se separan con dos puntos y las listas comienzan con un guión en YAML.

# %% [markdown]
# Los tipos de datos más comunes que se utilizan en YAML son:

# %% [markdown]
# * Números
# * Instrumentos de cuerda
# * Valores nulos
# * Booleano
# * Fechas y marcas de tiempo
# * Secuencias
# * Valores anidados

# %%
# base de datos obtenida de Kaggle sobre "Women's Big Bash League matches"
import yaml  # paquete yaml

with open(r'1023679.yaml') as file:
    doc = yaml.load(file, Loader=yaml.FullLoader)  # la función yaml.load convierte un documento YAML en un objeto Python

    sort_file = yaml.dump(doc, sort_keys=True)  # La función yaml.dump acepta un objeto Python y produce un documento YAML
    print(sort_file)
# Out:
# info:
#   city: Bendigo
#   competition: Women's Big Bash League
#   dates:
#   - '2016-12-18'
#   gender: female
#   match_type: T20
#   outcome:
#     eliminator: Hobart Hurricanes
#     result: tie
#   overs: 20
#   player_of_match:
#   - AE Satterthwaite
#   teams:
#   - Hobart Hurricanes
#   - Melbourne Renegades
#   toss:
#     decision: field
#     winner: Melbourne Renegades
#   umpires:
#   - D Brigham
#   - S Brne
#   venue: Queen Elizabeth II Oval
# innings:
# - 1st innings:
#     deliveries:
#     - 0.1:
#         batsman: HK Matthews
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 0.2:
#         batsman: G Redmayne
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.3:
#         batsman: G Redmayne
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 0.4:
#         batsman: G Redmayne
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.5:
#         batsman: G Redmayne
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.6:
#         batsman: G Redmayne
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 1.1:
#         batsman: HK Matthews
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.2:
#         batsman: HK Matthews
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.3:
#         batsman: HK Matthews
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.4:
#         batsman: HK Matthews
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 1.5:
#         batsman: HK Matthews
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.6:
#         batsman: HK Matthews
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 2.1:
#         batsman: G Redmayne
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 2.2:
#         batsman: HK Matthews
#         bowler: LMM Tahuhu
#         extras:
#           wides: 1
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 2.3:
#         batsman: HK Matthews
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 2.4:
#         batsman: HK Matthews
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           kind: caught and bowled
#           player_out: HK Matthews
#     - 2.5:
#         batsman: HC Knight
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 2.6:
#         batsman: HC Knight
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 2.7:
#         batsman: G Redmayne
#         bowler: LMM Tahuhu
#         non_striker: HC Knight
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.1:
#         batsman: HC Knight
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 3.2:
#         batsman: HC Knight
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.3:
#         batsman: HC Knight
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.4:
#         batsman: HC Knight
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.5:
#         batsman: HC Knight
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 3.6:
#         batsman: G Redmayne
#         bowler: M Strano
#         non_striker: HC Knight
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.1:
#         batsman: HC Knight
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.2:
#         batsman: HC Knight
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.3:
#         batsman: HC Knight
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.4:
#         batsman: HC Knight
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.5:
#         batsman: HC Knight
#         bowler: LMM Tahuhu
#         non_striker: G Redmayne
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 4.6:
#         batsman: G Redmayne
#         bowler: LMM Tahuhu
#         non_striker: HC Knight
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.1:
#         batsman: HC Knight
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - NA Plane
#           kind: caught
#           player_out: HC Knight
#     - 5.2:
#         batsman: G Redmayne
#         bowler: M Strano
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.3:
#         batsman: G Redmayne
#         bowler: M Strano
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.4:
#         batsman: G Redmayne
#         bowler: M Strano
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.5:
#         batsman: G Redmayne
#         bowler: M Strano
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 5.6:
#         batsman: G Redmayne
#         bowler: M Strano
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.1:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.2:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: G Redmayne
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 6.3:
#         batsman: G Redmayne
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 6.4:
#         batsman: G Redmayne
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.5:
#         batsman: G Redmayne
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.6:
#         batsman: G Redmayne
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.1:
#         batsman: G Redmayne
#         bowler: M Strano
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 7.2:
#         batsman: G Redmayne
#         bowler: M Strano
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.3:
#         batsman: AE Satterthwaite
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 7.4:
#         batsman: AE Satterthwaite
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 7.5:
#         batsman: AE Satterthwaite
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 7.6:
#         batsman: AE Satterthwaite
#         bowler: M Strano
#         non_striker: G Redmayne
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 8.1:
#         batsman: G Redmayne
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 8.2:
#         batsman: G Redmayne
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 8.3:
#         batsman: G Redmayne
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           kind: run out
#           player_out: G Redmayne
#     - 8.4:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: EA Burns
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 8.5:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: EA Burns
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.6:
#         batsman: EA Burns
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.1:
#         batsman: EA Burns
#         bowler: S Molineux
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.2:
#         batsman: AE Satterthwaite
#         bowler: S Molineux
#         non_striker: EA Burns
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 9.3:
#         batsman: AE Satterthwaite
#         bowler: S Molineux
#         non_striker: EA Burns
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 9.4:
#         batsman: AE Satterthwaite
#         bowler: S Molineux
#         non_striker: EA Burns
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.5:
#         batsman: EA Burns
#         bowler: S Molineux
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.6:
#         batsman: AE Satterthwaite
#         bowler: S Molineux
#         non_striker: EA Burns
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.1:
#         batsman: AE Satterthwaite
#         bowler: M Brown
#         non_striker: EA Burns
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.2:
#         batsman: EA Burns
#         bowler: M Brown
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 10.3:
#         batsman: EA Burns
#         bowler: M Brown
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.4:
#         batsman: AE Satterthwaite
#         bowler: M Brown
#         non_striker: EA Burns
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 10.5:
#         batsman: AE Satterthwaite
#         bowler: M Brown
#         non_striker: EA Burns
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 10.6:
#         batsman: AE Satterthwaite
#         bowler: M Brown
#         non_striker: EA Burns
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 11.1:
#         batsman: EA Burns
#         bowler: S Molineux
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.2:
#         batsman: AE Satterthwaite
#         bowler: S Molineux
#         non_striker: EA Burns
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 11.3:
#         batsman: AE Satterthwaite
#         bowler: S Molineux
#         non_striker: EA Burns
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.4:
#         batsman: EA Burns
#         bowler: S Molineux
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.5:
#         batsman: AE Satterthwaite
#         bowler: S Molineux
#         non_striker: EA Burns
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.6:
#         batsman: EA Burns
#         bowler: S Molineux
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 12.1:
#         batsman: EA Burns
#         bowler: M Brown
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - GM Harris
#           kind: caught
#           player_out: EA Burns
#     - 12.2:
#         batsman: CL Hall
#         bowler: M Brown
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 12.3:
#         batsman: CL Hall
#         bowler: M Brown
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 12.4:
#         batsman: CL Hall
#         bowler: M Brown
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 12.5:
#         batsman: AE Satterthwaite
#         bowler: M Brown
#         non_striker: CL Hall
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 12.6:
#         batsman: AE Satterthwaite
#         bowler: M Brown
#         non_striker: CL Hall
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 13.1:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 13.2:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 13.3:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 3
#           extras: 0
#           total: 3
#     - 13.4:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: CL Hall
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 13.5:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: CL Hall
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.6:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.1:
#         batsman: CL Hall
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.2:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: CL Hall
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 14.3:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: CL Hall
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 14.4:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: CL Hall
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 14.5:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: CL Hall
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.6:
#         batsman: CL Hall
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.1:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 15.2:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 15.3:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.4:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: CL Hall
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.5:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 15.6:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 16.1:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: CL Hall
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.2:
#         batsman: CL Hall
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 16.3:
#         batsman: CL Hall
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.4:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         extras:
#           legbyes: 1
#         non_striker: CL Hall
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 16.5:
#         batsman: CL Hall
#         bowler: NM Goodwin
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.6:
#         batsman: AE Satterthwaite
#         bowler: NM Goodwin
#         non_striker: CL Hall
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 17.1:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 17.2:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: CL Hall
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 17.3:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: CL Hall
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 17.4:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: CL Hall
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 17.5:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 17.6:
#         batsman: CL Hall
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - RH Priest
#           kind: caught
#           player_out: CL Hall
#     - 18.1:
#         batsman: AE Satterthwaite
#         bowler: LMM Tahuhu
#         non_striker: V Pyke
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 18.2:
#         batsman: V Pyke
#         bowler: LMM Tahuhu
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 18.3:
#         batsman: V Pyke
#         bowler: LMM Tahuhu
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 18.4:
#         batsman: AE Satterthwaite
#         bowler: LMM Tahuhu
#         non_striker: V Pyke
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 18.5:
#         batsman: V Pyke
#         bowler: LMM Tahuhu
#         extras:
#           wides: 1
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 18.6:
#         batsman: V Pyke
#         bowler: LMM Tahuhu
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 18.7:
#         batsman: AE Satterthwaite
#         bowler: LMM Tahuhu
#         non_striker: V Pyke
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.1:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: V Pyke
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.2:
#         batsman: V Pyke
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 19.3:
#         batsman: V Pyke
#         bowler: GM Harris
#         non_striker: AE Satterthwaite
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.4:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: V Pyke
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 19.5:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: V Pyke
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 19.6:
#         batsman: AE Satterthwaite
#         bowler: GM Harris
#         non_striker: V Pyke
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     team: Hobart Hurricanes
# - 2nd innings:
#     deliveries:
#     - 0.1:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.2:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.3:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.4:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.5:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 0.6:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 1.1:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: GM Harris
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.2:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: GM Harris
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.3:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: GM Harris
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.4:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: GM Harris
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 1.5:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: GM Harris
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.6:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: GM Harris
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 2.1:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 2.2:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 2.3:
#         batsman: RH Priest
#         bowler: V Pyke
#         non_striker: GM Harris
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 2.4:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 2.5:
#         batsman: GM Harris
#         bowler: V Pyke
#         non_striker: RH Priest
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 2.6:
#         batsman: RH Priest
#         bowler: V Pyke
#         non_striker: GM Harris
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.1:
#         batsman: GM Harris
#         bowler: AE Satterthwaite
#         non_striker: RH Priest
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 3.2:
#         batsman: RH Priest
#         bowler: AE Satterthwaite
#         non_striker: GM Harris
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.3:
#         batsman: RH Priest
#         bowler: AE Satterthwaite
#         non_striker: GM Harris
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 3.4:
#         batsman: RH Priest
#         bowler: AE Satterthwaite
#         non_striker: GM Harris
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 3.5:
#         batsman: RH Priest
#         bowler: AE Satterthwaite
#         non_striker: GM Harris
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.6:
#         batsman: RH Priest
#         bowler: AE Satterthwaite
#         non_striker: GM Harris
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.1:
#         batsman: GM Harris
#         bowler: HK Matthews
#         non_striker: RH Priest
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - EA Burns
#           kind: caught
#           player_out: GM Harris
#     - 4.2:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.3:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.4:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 4.5:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.6:
#         batsman: RH Priest
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - AE Satterthwaite
#           kind: caught
#           player_out: RH Priest
#     - 5.1:
#         batsman: DN Wyatt
#         bowler: AE Satterthwaite
#         extras:
#           wides: 1
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 5.2:
#         batsman: DN Wyatt
#         bowler: AE Satterthwaite
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 5.3:
#         batsman: KL Britt
#         bowler: AE Satterthwaite
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 5.4:
#         batsman: DN Wyatt
#         bowler: AE Satterthwaite
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.5:
#         batsman: DN Wyatt
#         bowler: AE Satterthwaite
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.6:
#         batsman: DN Wyatt
#         bowler: AE Satterthwaite
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 5.7:
#         batsman: KL Britt
#         bowler: AE Satterthwaite
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.1:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 6.2:
#         batsman: KL Britt
#         bowler: K Fryett
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 6.3:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 6.4:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.5:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.6:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 7.1:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 7.2:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 7.3:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 7.4:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 7.5:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 7.6:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 8.1:
#         batsman: DN Wyatt
#         bowler: B Hepburn
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 8.2:
#         batsman: DN Wyatt
#         bowler: B Hepburn
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.3:
#         batsman: KL Britt
#         bowler: B Hepburn
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.4:
#         batsman: DN Wyatt
#         bowler: B Hepburn
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 8.5:
#         batsman: DN Wyatt
#         bowler: B Hepburn
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 8.6:
#         batsman: DN Wyatt
#         bowler: B Hepburn
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 9.1:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 9.2:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.3:
#         batsman: DN Wyatt
#         bowler: C Raack
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.4:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 9.5:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.6:
#         batsman: DN Wyatt
#         bowler: C Raack
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.1:
#         batsman: DN Wyatt
#         bowler: B Hepburn
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 10.2:
#         batsman: DN Wyatt
#         bowler: B Hepburn
#         extras:
#           byes: 1
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 10.3:
#         batsman: KL Britt
#         bowler: B Hepburn
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.4:
#         batsman: DN Wyatt
#         bowler: B Hepburn
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.5:
#         batsman: KL Britt
#         bowler: B Hepburn
#         non_striker: DN Wyatt
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 10.6:
#         batsman: KL Britt
#         bowler: B Hepburn
#         non_striker: DN Wyatt
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 11.1:
#         batsman: DN Wyatt
#         bowler: C Raack
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 11.2:
#         batsman: DN Wyatt
#         bowler: C Raack
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.3:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 11.4:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.5:
#         batsman: DN Wyatt
#         bowler: C Raack
#         extras:
#           noballs: 1
#         non_striker: KL Britt
#         runs:
#           batsman: 4
#           extras: 1
#           total: 5
#     - 11.6:
#         batsman: DN Wyatt
#         bowler: C Raack
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.7:
#         batsman: KL Britt
#         bowler: C Raack
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 12.1:
#         batsman: KL Britt
#         bowler: K Fryett
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 12.2:
#         batsman: KL Britt
#         bowler: K Fryett
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 12.3:
#         batsman: KL Britt
#         bowler: K Fryett
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 12.4:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 12.5:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 12.6:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.1:
#         batsman: DN Wyatt
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.2:
#         batsman: KL Britt
#         bowler: HK Matthews
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 13.3:
#         batsman: KL Britt
#         bowler: HK Matthews
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 13.4:
#         batsman: KL Britt
#         bowler: HK Matthews
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.5:
#         batsman: DN Wyatt
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.6:
#         batsman: KL Britt
#         bowler: HK Matthews
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.1:
#         batsman: KL Britt
#         bowler: K Fryett
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.2:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.3:
#         batsman: KL Britt
#         bowler: K Fryett
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.4:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.5:
#         batsman: KL Britt
#         bowler: K Fryett
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.6:
#         batsman: DN Wyatt
#         bowler: K Fryett
#         non_striker: KL Britt
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 15.1:
#         batsman: KL Britt
#         bowler: AE Satterthwaite
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.2:
#         batsman: DN Wyatt
#         bowler: AE Satterthwaite
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 15.3:
#         batsman: DN Wyatt
#         bowler: AE Satterthwaite
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.4:
#         batsman: KL Britt
#         bowler: AE Satterthwaite
#         non_striker: DN Wyatt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 15.5:
#         batsman: KL Britt
#         bowler: AE Satterthwaite
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.6:
#         batsman: DN Wyatt
#         bowler: AE Satterthwaite
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 16.1:
#         batsman: KL Britt
#         bowler: V Pyke
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.2:
#         batsman: DN Wyatt
#         bowler: V Pyke
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.3:
#         batsman: KL Britt
#         bowler: V Pyke
#         non_striker: DN Wyatt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.4:
#         batsman: DN Wyatt
#         bowler: V Pyke
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 16.5:
#         batsman: DN Wyatt
#         bowler: V Pyke
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 16.6:
#         batsman: DN Wyatt
#         bowler: V Pyke
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 17.1:
#         batsman: DN Wyatt
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 17.2:
#         batsman: DN Wyatt
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - HC Knight
#           kind: caught
#           player_out: DN Wyatt
#     - 17.3:
#         batsman: S Molineux
#         bowler: HK Matthews
#         non_striker: KL Britt
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 17.4:
#         batsman: KL Britt
#         bowler: HK Matthews
#         non_striker: S Molineux
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 17.5:
#         batsman: KL Britt
#         bowler: HK Matthews
#         non_striker: S Molineux
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - G Redmayne
#           kind: caught
#           player_out: KL Britt
#     - 17.6:
#         batsman: M Strano
#         bowler: HK Matthews
#         non_striker: S Molineux
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 18.1:
#         batsman: S Molineux
#         bowler: V Pyke
#         non_striker: M Strano
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 18.2:
#         batsman: S Molineux
#         bowler: V Pyke
#         non_striker: M Strano
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 18.3:
#         batsman: S Molineux
#         bowler: V Pyke
#         extras:
#           wides: 1
#         non_striker: M Strano
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 18.4:
#         batsman: S Molineux
#         bowler: V Pyke
#         non_striker: M Strano
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 18.5:
#         batsman: S Molineux
#         bowler: V Pyke
#         non_striker: M Strano
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 18.6:
#         batsman: S Molineux
#         bowler: V Pyke
#         non_striker: M Strano
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 18.7:
#         batsman: M Strano
#         bowler: V Pyke
#         non_striker: S Molineux
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.1:
#         batsman: M Strano
#         bowler: AE Satterthwaite
#         non_striker: S Molineux
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.2:
#         batsman: S Molineux
#         bowler: AE Satterthwaite
#         non_striker: M Strano
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 19.3:
#         batsman: S Molineux
#         bowler: AE Satterthwaite
#         non_striker: M Strano
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.4:
#         batsman: M Strano
#         bowler: AE Satterthwaite
#         non_striker: S Molineux
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 19.5:
#         batsman: M Strano
#         bowler: AE Satterthwaite
#         non_striker: S Molineux
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#         wicket:
#           kind: run out
#           player_out: S Molineux
#     - 19.6:
#         batsman: M Strano
#         bowler: AE Satterthwaite
#         non_striker: LMM Tahuhu
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           kind: run out
#           player_out: M Strano
#     team: Melbourne Renegades
# - Melbourne Renegades Super Over:
#     deliveries:
#     - 0.1:
#         batsman: GM Harris
#         bowler: AE Satterthwaite
#         non_striker: RH Priest
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 0.2:
#         batsman: GM Harris
#         bowler: AE Satterthwaite
#         non_striker: RH Priest
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 0.3:
#         batsman: GM Harris
#         bowler: AE Satterthwaite
#         non_striker: RH Priest
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 0.4:
#         batsman: RH Priest
#         bowler: AE Satterthwaite
#         non_striker: GM Harris
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 0.5:
#         batsman: RH Priest
#         bowler: AE Satterthwaite
#         extras:
#           byes: 2
#         non_striker: GM Harris
#         runs:
#           batsman: 0
#           extras: 2
#           total: 2
#     - 0.6:
#         batsman: RH Priest
#         bowler: AE Satterthwaite
#         non_striker: GM Harris
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     team: Melbourne Renegades
# - Hobart Hurricanes Super Over:
#     deliveries:
#     - 0.1:
#         batsman: AE Satterthwaite
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - DN Wyatt
#           kind: caught
#           player_out: AE Satterthwaite
#     - 0.2:
#         batsman: HK Matthews
#         bowler: LMM Tahuhu
#         non_striker: EA Burns
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 0.3:
#         batsman: HK Matthews
#         bowler: LMM Tahuhu
#         non_striker: EA Burns
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 0.4:
#         batsman: EA Burns
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 0.5:
#         batsman: EA Burns
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 0.6:
#         batsman: EA Burns
#         bowler: LMM Tahuhu
#         non_striker: HK Matthews
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     team: Hobart Hurricanes
# meta:
#   created: '2020-08-15'
#   data_version: 0.9
#   revision: 1

# %% [markdown]
# ### JSON vs YAML

# %% [markdown]
# Con respecto a legibilidad y complejidad el objetivo del diseño de JSON es ser lo más simple posible y universalmente utilizable. Por tanto, esto ha reducido la legibilidad de los datos hasta cierto punto. Por el contrario, el objetivo de diseño de YAML es proporcionar un buen formato legible por humanos y proporcionar soporte para serializar estructuras de datos nativas arbitrarias. Así que esto ha aumentado la legibilidad de los archivos YAML pero ha hecho que el análisis y la generación de archivos sean algo complejos.

# %% [markdown]
# En lo relativo a rendimiento de serialización JSON es el ganador debido a la capacidad de analizar rápida y fácilmente datos serializados JSON con su diseño más simple. Y esto ha hecho que JSON se haya convertido en el formato de intercambio de datos más utilizado para aplicaciones y servicios web entre los desarrolladores.

# %% [markdown]
# ### Otras cuestiones

# %% [markdown]
# ####  ¿Se pueden leer con spark?

# %% [markdown]
# Spark está diseñado para funcionar con Python, Java, Scala y SQL y los tipos de datos que puede leer son los siguientes:

# %% [markdown]
# ![tiposdatosSpark.PNG](attachment:tiposdatosSpark.PNG)

# %% [markdown]
# #### ¿Qué tipo de bases de datos No SQL usa estructuras de datos similares?

# %% [markdown]
# Las bases de datos NoSQL son sistemas de almacenamiento de información que no cumplen con el esquema entidad–relación. Tampoco utilizan una estructura de datos en forma de tabla donde se van almacenando los datos sino que para el almacenamiento hacen uso de otros formatos como clave–valor, mapeo de columnas o grafos. Además, son estructuras que nos permiten almacenar información en aquellas situaciones en las que las bases de datos relacionales generan ciertos problemas debido principalmente a problemas de escalabilidad y rendimiento.

# %% [markdown]
# Algunos tipos de bases de datos No SQL que usan estructuras de datos similares a JSON y YAML, es decir, con estructura de diccionario clave-valor son:

# %% [markdown]
# * Mongo DB
# * Couch DB

# %% [markdown]
# ## Referencias

# %% [markdown]
# * Bases de datos NoSQL.Qué son y tipos que nos podemos encontrar. Disponible en: https://www.acens.com/wp-content/images/2014/02/bbdd-nosql-wp-acens.pdf
# * Conoce que es un YAML. Disponible en: https://fercontreras.com/conoce-que-es-un-yaml-e18e9d21ade4
# * Datos abiertos de la Comunidad de Madrid. Covid 19 -TIA por Municipios y Distritos de Madrid dataset. Disponible en: https://datos.comunidad.madrid/catalogo/organization/f483a299-1775-4d87-a2f7-39bf554735a1?res_format=JSON
# * JSON vs YAML. Disponible en: https://levelup.gitconnected.com/json-vs-yaml-6aa0243aefc6
# * Reading and Writing YAML to a File in Python. Disponible en: https://stackabuse.com/reading-and-writing-yaml-to-a-file-in-python/
# * Trabajando con JSON. MDN web docs. Disponible en: https://developer.mozilla.org/es/docs/Learn/JavaScript/Objects/JSON
# * What is the difference between YAML and JSON? Disponible en: https://www.geeksforgeeks.org/what-is-the-difference-between-yaml-and-json/
# *  Women's Big Bash League matches dataset (Kaggle). Disponible en: https://www.kaggle.com/maneesh99/womens-big-bash-league-matches
